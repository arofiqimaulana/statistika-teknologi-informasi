# %%
import pandas as pd
from sklearn import preprocessing

# %%
# import dataset
df = pd.read_csv('Negara Impor Kendaraan Bermotor.csv')

# %%
# preview datasets
df
# Out:
#         Negara Asal  Total Impor (juta US$)  Tahun  Negara_Code
# 0            Jepang                   644.3   2018            3
# 1         Tiongkok2                    84.2   2018            9
# 2          Thailand                   666.0   2018            8
# 3             India                   334.3   2018            1
# 4            Jerman                   110.3   2018            4
# 5     Korea Selatan                   215.2   2018            5
# 6           Inggris                    21.2   2018            2
# 7            Swedia                   103.0   2018            7
# 8   Amerika Serikat                    18.5   2018            0
# 9         Singapura                     5.2   2018            6
# 10           Jepang                   890.0   2019            3
# 11        Tiongkok2                   137.7   2019            9
# 12         Thailand                   607.7   2019            8
# 13            India                   455.5   2019            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Negara Asal             50 non-null     object
#  1   Total Impor (juta US$)  50 non-null     float64
#  2   Tahun                   50 non-null     int64
#  3   Negara_Code             50 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.7+ KB

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['Negara_Code']= label_encoder.fit_transform(df['Negara Asal'])

# %%
df.head(9)
# Out:
#        Negara Asal  Total Impor (juta US$)  Tahun  Negara_Code
# 0           Jepang                   644.3   2018            3
# 1        Tiongkok2                    84.2   2018            9
# 2         Thailand                   666.0   2018            8
# 3            India                   334.3   2018            1
# 4           Jerman                   110.3   2018            4
# 5    Korea Selatan                   215.2   2018            5
# 6          Inggris                    21.2   2018            2
# 7           Swedia                   103.0   2018            7
# 8  Amerika Serikat                    18.5   2018            0

# %% [markdown]
# ### Jenis Data
#
# - Negara_Code : Kategorik, Skala Nominal
# - Total Impor : Numerik, Skala Rasio, Data Kontinue

# %% [markdown]
# ## Reference
# - https://www.bps.go.id/statictable/2014/09/08/1048/nilai-impor-kendaraan-bermotor-menurut-negara-asal-utama-nilai-cif-juta-us-2000-2022.html
